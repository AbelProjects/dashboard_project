# %%
import pickle
import pandas as pd

# %%
with open('prices.pickle', 'rb') as file:
    data = pickle.load(file)

# %%
t = []
for shop in data.keys():
    t.extend(data[shop])

# %%
t_pd = pd.DataFrame(t)

# %%
t_pd
# Out:
#                                                    name  priceBefore  \
# 0                               Конфеты Сладония, 100 г       428.99
# 1          Паштет деликатесный, Hame, мясо птицы, 105 г        71.49
# 2              Корм для кошек Felix, утка-морковь, 85 г        32.99
# 3                Чай Ahmad Tea Earl Grey, черный, 100 г       219.99
# 4     Ополаскиватель для посудомоечных машин Finish,...       499.99
# ...                                                 ...          ...
# 7176             Напиток спиртной Абсент Люксардо 0,75л      2590.00
# 7177                Сыр Тильзитер Буренка клаб 45% 180г       199.90
# 7178  Вино Коно Сур Токорнал Шардоне белое полусухое...       899.00
# 7179  Напиток безалкогольный газированный Калинов ли...        89.90
# 7180                                Салат Крабовый 200г       169.00
#
#       priceAfter  amount amountUnit  discount             startDate  \
# 0         299.99  100.00          г      31.0  2022-09-01T00:00:00Z
# ...
