# %%
import pickle
import pandas as pd

# %%
with open('data/prices_2022_09_15.pickle', 'rb') as file:
    data1 = pd.DataFrame(pickle.load(file))

# %%
data1
# Out:
#                                                    name  priceBefore  \
# 0     Стиральный Порошок Tide Альпийская СВежесть, 3 кг       699.99
# 1                   Стиральный Порошок Tide Color, 3 кг       699.99
# 2        Порошок для стирки Tide Color, детский, 2,4 кг       649.99
# 3                                   Пшено Увелка, 800 г        89.99
# 4     Тесто слоеное дрожжевое; бездрожжевое, Морозко...       299.99
# ...                                                 ...          ...
# 6126             Напиток спиртной Абсент Люксардо 0,75л      2590.00
# 6127                Сыр Тильзитер Буренка клаб 45% 180г       199.90
# 6128  Напиток безалкогольный газированный Калинов ли...        89.90
# 6129  Сыр Тильзитер Сырная долина 50% 1кг,Для держат...       899.00
# 6130                                Салат Крабовый 200г       169.00
#
#       priceAfter  amount amountUnit  discount             startDate  \
# 0         399.99    3.00         кг      43.0  2022-09-13T00:00:00Z
# ...

# %%
with open('data/prices_2022_10_17.pickle', 'rb') as file:
    data2 = pd.DataFrame(pickle.load(file))

# %%
data2.columns == data1.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
t_pd = pd.DataFrame(data)

# %%
t_pd
# Out:
#                                                    name  priceBefore  \
# 0         Стиральный порошок Tide Аквапудра Color, 3 кг       699.99
# 1     Стиральный порошок Tide Аквапудра Альпийская с...       699.99
# 2     Пельмени Бульмени, с говядиной и свининой, Гор...       339.98
# 3                         Филе куриное, Петелинка, 1 кг       342.49
# 4               Кофе Jacobs Monarch, растворимый, 210 г       829.99
# ...                                                 ...          ...
# 5128                             Джин Инглиш парк 0,25л       249.00
# 5129  СТМ Влажные салфетки очищающие Пудровая космет...        39.90
# 5130  Кофе Бушидо Ред Катана молотый 227г,Для держат...       599.00
# 5131        Хлеб Ремесленный заварной Рижский хлеб 430г       119.00
# 5132              Сыр творожный Шонфилд зелень 65% 140г       119.90
#
#       priceAfter  amount amountUnit  discount             startDate  \
# 0         399.99    3.00         кг      43.0  2022-10-11T00:00:00Z
# ...

# %%
import pickle

# %%
t = [1,2,3]
b = [2,1,4]

with open('file.pickle', 'wb') as f:
    pickle.dump(t, f, protocol=pickle.HIGHEST_PROTOCOL)
file.close()

# %%
with open('file.pickle', 'wb') as f:
    data = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Input In [105], in <cell line: 1>()
#       1 with open('file.pickle', 'wb') as f:
# ----> 2     data = pickle.load(f)
#
# UnsupportedOperation: read

# %%
def download_parser_operator(ds, **context):
    
    home_path = f"dags/data/history_prices/ds={ds}"
    pathlib.Path(home_path).mkdir(parents=True, exist_ok=True)
    
    
    with open(posixpath.join(home_path, "prices.pickle"), "w") as f:
        f.write() # write and save

# %%
with open('file.pickle', 'ab+') as f:
    pickle.dump(b, f, protocol=pickle.HIGHEST_PROTOCOL)
file.close()

# %%
with open('file.pickle', 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
# [1, 2, 3]

# %%
data1
# Out:
# [2, 1, 4]

# %%
import parser as pr

# %%
shop_list = ['5ka', 'magnit-univer', 'perekrestok', 'dixy',
                 'lenta-super', 'vkusvill_offline', 'mgnl', 'azbuka_vkusa']
data = pr.parse_shop_list(city='moskva', shop_list=shop_list, page_range=10)
pr.save_results(data)

# %%
d = pd.read_csv('data/prices_2022_10_17.csv')

# %%
d
# Out:
#       Unnamed: 0                                               name  \
# 0              0      Стиральный порошок Tide Аквапудра Color, 3 кг
# 1              1  Стиральный порошок Tide Аквапудра Альпийская с...
# 2              2  Пельмени Бульмени, с говядиной и свининой, Гор...
# 3              3                      Филе куриное, Петелинка, 1 кг
# 4              4            Кофе Jacobs Monarch, растворимый, 210 г
# ...          ...                                                ...
# 5206        1045                             Джин Инглиш парк 0,25л
# 5207        1046  СТМ Влажные салфетки очищающие Пудровая космет...
# 5208        1047  Кофе Бушидо Ред Катана молотый 227г,Для держат...
# 5209        1048        Хлеб Ремесленный заварной Рижский хлеб 430г
# 5210        1049              Сыр творожный Шонфилд зелень 65% 140г
#
#       priceBefore  priceAfter  amount amountUnit  discount  \
# 0          699.99      399.99    3.00         кг      43.0
# ...

# %%
data.to_csv('asfa', index=False)
