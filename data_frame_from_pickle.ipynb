# %%
import pickle
import pandas as pd

# %%
with open('data/prices_2022_09_14.pickle', 'rb') as file:
    data = pickle.load(file)

# %%
data
# Out:
# [{'name': 'Порошок для стирки Tide Color, детский, 2,4 кг',
#   'priceBefore': 649.99,
#   'priceAfter': 319.99,
#   'amount': 2.4,
#   'amountUnit': 'кг',
#   'discount': 51.0,
#   'startDate': '2022-09-01T00:00:00Z',
#   'endDate': '2022-09-30T00:00:00Z',
#   'city': 'moskva',
#   'shop': '5ka',
#   'page': 0,
#   'processed_date': '2022-09-14'},
#  {'name': 'Стиральный Порошок Tide Альпийская СВежесть, 3 кг',
#   'priceBefore': 699.99,
#   'priceAfter': 399.99,
#   'amount': 3.0,
#   'amountUnit': 'кг',
#   'discount': 43.0,
#   'startDate': '2022-09-13T00:00:00Z',
#   'endDate': '2022-09-19T00:00:00Z',
#   'city': 'moskva',
#   'shop': '5ka',
#   'page': 0,
#   'processed_date': '2022-09-14'},
#  {'name': 'Стиральный Порошок Tide Color, 3 кг',
#   'priceBefore': 699.99,
#   'priceAfter': 399.99,
#   'amount': 3.0,
#   'amountUnit': 'кг',
#   'discount': 43.0,
#   'startDate': '2022-09-13T00:00:00Z',
#   'endDate': '2022-09-19T00:00:00Z',
#   'city': 'moskva',
#   'shop': '5ka',
# ...

# %%
t_pd = pd.DataFrame(data)

# %%
t_pd
# Out:
#                                                   name  priceBefore  \
# 0       Порошок для стирки Tide Color, детский, 2,4 кг       649.99
# 1    Стиральный Порошок Tide Альпийская СВежесть, 3 кг       699.99
# 2                  Стиральный Порошок Tide Color, 3 кг       699.99
# 3    Тесто слоеное дрожжевое; бездрожжевое, Морозко...       299.99
# 4                     Средства для стирки Persil, 3 кг       684.99
# ..                                                 ...          ...
# 345                 Пудинг Село зеленое ваниль 3% 120г        59.90
# 346                          Конфеты Замоскворечье 1кг       999.00
# 347  Вафли глазированные с арахисом и фундуком Коло...        99.90
# 348               Коньяк Старый Кенигсберг 4 года 0,5л       959.00
# 349  Икра деликатесная классическая деликатесная Бр...       229.00
#
#      priceAfter  amount amountUnit  discount             startDate  \
# 0        319.99     2.4         кг      51.0  2022-09-01T00:00:00Z
# ...

# %%
import pickle

# %%
t = [1,2,3]
b = [2,1,4]

with open('file.pickle', 'wb') as f:
    pickle.dump(t, f, protocol=pickle.HIGHEST_PROTOCOL)
file.close()

# %%
with open('file.pickle', 'wb') as f:
    data = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Input In [105], in <cell line: 1>()
#       1 with open('file.pickle', 'wb') as f:
# ----> 2     data = pickle.load(f)
#
# UnsupportedOperation: read

# %%
def download_parser_operator(ds, **context):
    
    home_path = f"dags/data/history_prices/ds={ds}"
    pathlib.Path(home_path).mkdir(parents=True, exist_ok=True)
    
    
    with open(posixpath.join(home_path, "prices.pickle"), "w") as f:
        f.write() # write and save

# %%
with open('file.pickle', 'ab+') as f:
    pickle.dump(b, f, protocol=pickle.HIGHEST_PROTOCOL)
file.close()

# %%
with open('file.pickle', 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
# [1, 2, 3]

# %%
data1
# Out:
# [2, 1, 4]
